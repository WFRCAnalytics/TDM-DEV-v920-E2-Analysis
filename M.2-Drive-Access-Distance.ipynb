# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly as pys
import ipywidgets as widgets
from ipywidgets import Layout
import os
import _global_scripts as gs

# %% [markdown]
# ## Purpose

# %% [markdown]
# **Investigation #6**: Average Drive Access Distance by Station (Model vs Observed)

# %% [markdown]
# ## Inputs

# %%
# get data from csv now
models_df = pd.read_csv("data-scenario/models.csv")

# Filter to only displayed models
summary_models = models_df[
    models_df["model_display"] & models_df["model_RID"].notna()
]

# Generate filenames and sourcenames
tdm_filenames = []
tdm_sourcenames = []

for _, row in summary_models.iterrows():
    scenario_id = row["scenario_id"]
    model_id = row["model_id"]
    model_name = row["model_name"]
    scenario_label = row["model_label"]  # e.g., "Recalib-RF2.5 - BY 2019"

    # File path matches copied filename pattern (without RUNID)
    link_path = f"data-scenario/{scenario_id}/{model_name}/transit_rider_summary_link.csv"

    # Optionally verify file exists before including
    if os.path.exists(link_path):
        tdm_filenames.append(link_path)
        tdm_sourcenames.append(f"{model_id}")
    else:
        print(f"⚠️ File not found: {link_path}")



df_obs_access_dist = pd.read_csv(r"data-obs/OBS_Access_Egress_Distances_v2.csv")
df_obs_ungrouped = pd.read_csv(r"data-obs/base_observed_ungrouped_pa.csv")
#df_obs_data = pd.read_csv(r"D:/GitHub/OBS-TDM-Ridership-Compare/2023-OBS-TDM-Compare/data/2019-OBS/2019 Final Weighted UTA OD Data - 2022-04-05 - processed.csv")7

# %%
def weighted_quantile(data, q, weights, factor):
    factored_weights = weights * factor
    rounded_weights = np.round(factored_weights).astype(int)
    repeat_data = np.repeat(data,rounded_weights).astype(float)

    return np.quantile(repeat_data, q)

def weighted_average(data, weights):
    return np.average(data, weights=weights)

# %% [markdown]
# ## TDM

# %%
# read in stations and summarize tdm results
df_stations1 = gs.df_stations[['station','N']]

# %%
df_tdm_brd = pd.DataFrame()

for tdm_filename, tdm_sourcename in zip(tdm_filenames, tdm_sourcenames):
    print(tdm_sourcename)
    df_tdm_links = pd.read_csv(tdm_filename, low_memory=False)

    # Merge to get boarding and alighting station names
    df_tdm_1 = (
        df_tdm_links
        .merge(df_stations1, left_on="B", right_on="N", how="left")
        .rename(columns={"station": "brd_station"})
        .merge(df_stations1, left_on="A", right_on="N", how="left")
        .rename(columns={"station": "alt_station"})
        .drop(columns=['N_x', 'N_y'])
        .copy()
    )

    # Filter out invalid data and keep specific access links
    df_tdm_2 = df_tdm_1[
        ((df_tdm_1["brd_station"].notna()) & (df_tdm_1["A"] < 10000)) |
        ((df_tdm_1["alt_station"].notna()) & (df_tdm_1["B"] < 10000))
    ].copy()

    df_tdm_2 = df_tdm_2[df_tdm_2["Mode"].isin([80, 11])].copy()
    df_tdm_2["FromSkim_CRT"] = pd.to_numeric(df_tdm_2["FromSkim_CRT"], errors="coerce")

    # Keep only drive access links and select necessary columns
    df_tdm_3 = df_tdm_2[['Mode', 'Period', 'AccessMode', 'brd_station', 'alt_station', 'Riders', 'Distance']].copy()

    # Aggregate data at boarding station level
    df_tdm_brd_source = (
        df_tdm_3
        .dropna(subset=["brd_station"])
        .groupby(['Mode', 'brd_station', "AccessMode"], as_index=False)
        .apply(lambda x: pd.Series({
            'Brd_PA': x['Riders'].sum(),
            'Dist_15': weighted_quantile(x['Distance'].values, 0.15, x['Riders'].values, 10000),
            'Dist_Med': weighted_quantile(x['Distance'].values, 0.5, x['Riders'].values, 10000),
            'Dist_85': weighted_quantile(x['Distance'].values, 0.85, x['Riders'].values, 10000),
            'Dist_Avg': weighted_average(x['Distance'].values, x['Riders'].values)
        }))
    )
    
    # Compute totals across all AccessModes
    df_tdm_brd_all = (
        df_tdm_3
        .dropna(subset=["brd_station"])
        .groupby(['Mode', 'brd_station'], as_index=False)
        .apply(lambda x: pd.Series({
            'Brd_PA': x['Riders'].sum(),
            'Dist_15': weighted_quantile(x['Distance'].values, 0.15, x['Riders'].values, 10000),
            'Dist_Med': weighted_quantile(x['Distance'].values, 0.5, x['Riders'].values, 10000),
            'Dist_85': weighted_quantile(x['Distance'].values, 0.85, x['Riders'].values, 10000),
            'Dist_Avg': weighted_average(x['Distance'].values, x['Riders'].values)
        }))
        .reset_index()
    )

    # Add "All" access mode
    df_tdm_brd_all["AccessMode"] = "All"

    # Combine both grouped and "All"
    df_tdm_brd_source = pd.concat([df_tdm_brd_source, df_tdm_brd_all], ignore_index=True)

    # Add metadata columns
    df_tdm_brd_source['Source'] = tdm_sourcename
    df_tdm_brd_source['station'] = df_tdm_brd_source['brd_station']
    df_tdm_brd_source['Notes'] = 'Boardings represent only direct boardings to CRT.'

    # Reorder and select final columns
    df_tdm_brd_source = df_tdm_brd_source[
        ['Source', 'station', 'AccessMode', 'Brd_PA', 'Dist_15', 'Dist_Med', 'Dist_85', 'Dist_Avg', 'Notes']
    ]

    # Append to the main DataFrame
    df_tdm_brd = pd.concat([df_tdm_brd, df_tdm_brd_source], ignore_index=True)

df_tdm_brd
# Out:
# v910-official__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# v910-official__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.14.4__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.14.4__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.16.2__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.16.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.17.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__RTP_MedDistAdj_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.4__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2359732935.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
#                      Source                   station AccessMode   Brd_PA  \
# 0    v910-official__BY_2019          01-OGDEN STATION       walk    73.18
# 1    v910-official__BY_2019            02-ROY STATION       walk   368.09
# 2    v910-official__BY_2019     03-CLEARFIELD STATION       walk   474.87
# 3    v910-official__BY_2019         04-LAYTON STATION       walk   128.15
# 4    v910-official__BY_2019     05-FARMINGTON STATION       walk   119.91
# ..                      ...                       ...        ...      ...
# 715        E2.18.4__BY_2019         11-DRAPER STATION        All  1122.41
# 716        E2.18.4__BY_2019           12-LEHI STATION        All  1267.44
# 717        E2.18.4__BY_2019  13-AMERICAN FORK STATION        All  1930.26
# 718        E2.18.4__BY_2019   14-OREM CENTRAL STATION        All  1143.69
# 719        E2.18.4__BY_2019  15-PROVO CENTRAL STATION        All   950.44
#
#      Dist_15  Dist_Med  Dist_85  Dist_Avg  \
# 0       0.28      0.44     0.83  0.469794
# 1       0.37      0.45     0.68  0.521878
# 2       0.29      0.63     0.64  0.524257
# 3       0.17      0.17     0.66  0.304063
# 4       0.17      0.17     0.82  0.300855
# ..       ...       ...      ...       ...
# 715     2.48      4.41     6.29  4.579222
# 716     1.97      3.40     6.29  3.953310
# 717     2.12      3.58     6.24  3.925441
# 718     1.99      3.52     5.26  3.631628
# 719     1.32      2.87     8.16  4.209532
#
#                                                  Notes
# 0    Boardings represent only direct boardings to CRT.
# 1    Boardings represent only direct boardings to CRT.
# 2    Boardings represent only direct boardings to CRT.
# 3    Boardings represent only direct boardings to CRT.
# 4    Boardings represent only direct boardings to CRT.
# ..                                                 ...
# 715  Boardings represent only direct boardings to CRT.
# 716  Boardings represent only direct boardings to CRT.
# 717  Boardings represent only direct boardings to CRT.
# 718  Boardings represent only direct boardings to CRT.
# 719  Boardings represent only direct boardings to CRT.
#
# [720 rows x 9 columns]

# %% [markdown]
# ## Observed

# %%
df_obs_1 = df_obs_ungrouped.merge(df_obs_access_dist, on = 'id')

# %%
boardings = df_obs_1.loc[df_obs_1['onoff'] == 'on']

boardings_total = (boardings.groupby(['station','AccessMode'])
                     .apply(lambda x: pd.Series({
                        'Brd_PA': sum(x['unlinked_weight_adj']),
                        'Dist_15': weighted_quantile(x['AcDist'].values, 0.15, x['unlinked_weight_adj'].values,10000),
                        'Dist_Med': weighted_quantile(x['AcDist'].values, 0.5, x['unlinked_weight_adj'].values,10000),
                        'Dist_85': weighted_quantile(x['AcDist'].values, 0.85, x['unlinked_weight_adj'].values,10000),
                        'Dist_Avg': weighted_average(x['AcDist'].values, x['unlinked_weight_adj'].values)

                     }))
                     .reset_index()
                  )

# Total across all access modes
boardings_all = (boardings.groupby('station')
    .apply(lambda x: pd.Series({
        'Brd_PA': sum(x['unlinked_weight_adj']),
        'Dist_15': weighted_quantile(x['AcDist'].values, 0.15, x['unlinked_weight_adj'].values, 10000),
        'Dist_Med': weighted_quantile(x['AcDist'].values, 0.5, x['unlinked_weight_adj'].values, 10000),
        'Dist_85': weighted_quantile(x['AcDist'].values, 0.85, x['unlinked_weight_adj'].values, 10000),
        'Dist_Avg': weighted_average(x['AcDist'].values, x['unlinked_weight_adj'].values)
    }))
    .reset_index()
)
boardings_all['AccessMode'] = 'All'

# Combine grouped + all
boardings_total = pd.concat([boardings_total, boardings_all], ignore_index=True)

boardings_total['Source'] = 'OBS'
boardings_total['Notes'] = 'Boardings represent all boardings, not just direct to CRT.'
boardings_total = boardings_total[['Source','station','AccessMode','Brd_PA','Dist_15','Dist_Med','Dist_85','Dist_Avg', 'Notes']]
boardings_total
# Out:
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\343415949.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boardings_total = (boardings.groupby(['station','AccessMode'])
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\343415949.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boardings_all = (boardings.groupby('station')
#    Source                       station AccessMode    Brd_PA   Dist_15  \
# 0     OBS              01-OGDEN STATION      drive  1359.419  2.099442
# 1     OBS              01-OGDEN STATION       walk   495.237  0.244400
# 2     OBS                02-ROY STATION      drive   669.648  1.232191
# 3     OBS                02-ROY STATION       walk   168.575  0.363893
# 4     OBS         03-CLEARFIELD STATION      drive   739.268  1.190000
# 5     OBS         03-CLEARFIELD STATION       walk   232.219  0.270308
# 6     OBS             04-LAYTON STATION      drive  1113.116  1.402450
# 7     OBS             04-LAYTON STATION       walk   384.134  0.313129
# 8     OBS         05-FARMINGTON STATION      drive   378.690  1.430000
# 9     OBS         05-FARMINGTON STATION       walk   120.055  0.150007
# 10    OBS        06-WOODS CROSS STATION      drive   594.331  1.764544
# 11    OBS        06-WOODS CROSS STATION       walk   173.169  0.387836
# 12    OBS       07-NORTH TEMPLE STATION      drive   335.673  1.333103
# 13    OBS       07-NORTH TEMPLE STATION       walk   661.147  0.135151
# 14    OBS  08-SALT LAKE CENTRAL STATION      drive   363.018  1.263301
# 15    OBS  08-SALT LAKE CENTRAL STATION       walk   529.444  0.149909
# 16    OBS     09-MURRAY CENTRAL STATION      drive  1029.668  1.445006
# 17    OBS     09-MURRAY CENTRAL STATION       walk   792.633  0.242633
# 18    OBS       10-SOUTH JORDAN STATION      drive   970.963  2.200000
# 19    OBS       10-SOUTH JORDAN STATION       walk   206.560  0.154715
# 20    OBS             11-DRAPER STATION      drive   935.648  2.838472
# 21    OBS             11-DRAPER STATION       walk   144.648  0.469682
# 22    OBS               12-LEHI STATION      drive  1128.372  2.350000
# 23    OBS               12-LEHI STATION       walk   292.189  0.272890
# 24    OBS      13-AMERICAN FORK STATION      drive  1410.593  2.090000
# 25    OBS      13-AMERICAN FORK STATION       walk   136.077  0.282029
# 26    OBS       14-OREM CENTRAL STATION      drive  1460.040  0.950000
# 27    OBS       14-OREM CENTRAL STATION       walk   360.640  0.076044
# 28    OBS      15-PROVO CENTRAL STATION      drive  2260.414  1.170000
# 29    OBS      15-PROVO CENTRAL STATION       walk   945.908  0.164252
# 30    OBS              01-OGDEN STATION        All  1854.656  0.453778
# 31    OBS                02-ROY STATION        All   838.223  0.641269
# 32    OBS         03-CLEARFIELD STATION        All   971.487  0.527209
# 33    OBS             04-LAYTON STATION        All  1497.250  0.937156
# 34    OBS         05-FARMINGTON STATION        All   498.745  0.882145
# 35    OBS        06-WOODS CROSS STATION        All   767.500  1.136129
# 36    OBS       07-NORTH TEMPLE STATION        All   996.820  0.147354
# 37    OBS  08-SALT LAKE CENTRAL STATION        All   892.462  0.180835
# 38    OBS     09-MURRAY CENTRAL STATION        All  1822.301  0.396391
# 39    OBS       10-SOUTH JORDAN STATION        All  1177.523  0.973882
# 40    OBS             11-DRAPER STATION        All  1080.296  1.673298
# 41    OBS               12-LEHI STATION        All  1420.561  0.810000
# 42    OBS      13-AMERICAN FORK STATION        All  1546.670  1.620000
# 43    OBS       14-OREM CENTRAL STATION        All  1820.680  0.468708
# 44    OBS      15-PROVO CENTRAL STATION        All  3206.322  0.373422
#
#     Dist_Med    Dist_85   Dist_Avg  \
# 0   4.350000   7.420000   5.370319
# 1   0.428609   1.160804   0.656307
# 2   3.040313   4.240000   3.393104
# 3   0.641269   1.046372   0.789633
# 4   3.040000   5.200000   3.241714
# 5   0.527209   1.000823   0.709644
# 6   2.350000   3.900000   2.940304
# 7   1.026735   1.948161   1.111841
# 8   2.640000   6.250000   4.072510
# 9   0.882145   2.067059   1.045497
# 10  2.920000   4.810000   3.716678
# 11  1.136129   1.934859   1.233335
# 12  5.240000  23.699179  10.832972
# 13  0.252570   0.841639   0.455427
# 14  2.660000   4.540000   2.955727
# 15  0.352628   1.457191   0.782259
# 16  3.984978   9.400000   5.125550
# 17  0.480580   1.289595   0.787929
# 18  4.282981   6.400000   4.547102
# 19  0.941236   1.405301   0.919064
# 20  4.540000   8.320000   5.075091
# 21  1.034810   1.613032   1.072952
# 22  4.270000   8.480000   5.398140
# 23  0.351125   1.679277   0.896353
# 24  3.980000   9.580000   5.402691
# 25  0.824947   0.921420   0.839018
# 26  2.850000   4.830000   3.319107
# 27  0.310929   0.605386   0.400700
# 28  2.790000   9.890000   4.727752
# 29  0.371521   1.103047   0.545255
# 30  3.303563   6.988511   4.111566
# 31  2.211849   4.128146   2.869520
# 32  2.120000   5.030000   2.636462
# 33  1.990000   3.361007   2.471194
# 34  2.030000   3.940000   3.343865
# 35  2.400000   4.600000   3.156368
# 36  0.583727   6.880000   3.950002
# 37  1.263301   3.250000   1.666339
# 38  1.720000   6.280000   3.238846
# 39  4.150000   6.040000   3.910675
# 40  4.190000   7.980000   4.539218
# 41  3.341861   7.370000   4.472187
# 42  3.500856   9.170000   5.001176
# 43  2.509974   4.700000   2.741029
# 44  1.810000   8.360000   3.493859
#
#                                                 Notes
# 0   Boardings represent all boardings, not just di...
# 1   Boardings represent all boardings, not just di...
# 2   Boardings represent all boardings, not just di...
# 3   Boardings represent all boardings, not just di...
# 4   Boardings represent all boardings, not just di...
# 5   Boardings represent all boardings, not just di...
# 6   Boardings represent all boardings, not just di...
# 7   Boardings represent all boardings, not just di...
# 8   Boardings represent all boardings, not just di...
# 9   Boardings represent all boardings, not just di...
# 10  Boardings represent all boardings, not just di...
# 11  Boardings represent all boardings, not just di...
# 12  Boardings represent all boardings, not just di...
# 13  Boardings represent all boardings, not just di...
# 14  Boardings represent all boardings, not just di...
# 15  Boardings represent all boardings, not just di...
# 16  Boardings represent all boardings, not just di...
# 17  Boardings represent all boardings, not just di...
# 18  Boardings represent all boardings, not just di...
# 19  Boardings represent all boardings, not just di...
# 20  Boardings represent all boardings, not just di...
# 21  Boardings represent all boardings, not just di...
# 22  Boardings represent all boardings, not just di...
# 23  Boardings represent all boardings, not just di...
# 24  Boardings represent all boardings, not just di...
# 25  Boardings represent all boardings, not just di...
# 26  Boardings represent all boardings, not just di...
# 27  Boardings represent all boardings, not just di...
# 28  Boardings represent all boardings, not just di...
# 29  Boardings represent all boardings, not just di...
# 30  Boardings represent all boardings, not just di...
# 31  Boardings represent all boardings, not just di...
# 32  Boardings represent all boardings, not just di...
# 33  Boardings represent all boardings, not just di...
# 34  Boardings represent all boardings, not just di...
# 35  Boardings represent all boardings, not just di...
# 36  Boardings represent all boardings, not just di...
# 37  Boardings represent all boardings, not just di...
# 38  Boardings represent all boardings, not just di...
# 39  Boardings represent all boardings, not just di...
# 40  Boardings represent all boardings, not just di...
# 41  Boardings represent all boardings, not just di...
# 42  Boardings represent all boardings, not just di...
# 43  Boardings represent all boardings, not just di...
# 44  Boardings represent all boardings, not just di...

# %% [markdown]
# ## Comparison of TDM and OBS

# %%
sumStats = pd.concat([boardings_total,df_tdm_brd],ignore_index=True)

# %%
def plotit(variable, access_mode):
    output.clear_output()  # Clear previous output before displaying new content
    global firstTime
    if firstTime:
    
        filtered_data = sumStats[sumStats['AccessMode'] == access_mode]
            
        # Create histogram
        fig = px.histogram(
            filtered_data, 
            x="station", 
            y=variable, 
            text_auto='.2s',
            color='Source', 
            barmode='group',
            height=400
        )
        fig.update_layout(
            xaxis_title="Station Name",
            yaxis_title=str(variable),
            legend_title="Model Version"
        )
        
        # Display the plot
        fig.show()
    
    else:
        firstTime = True

# %%
lstValues = list([
    'Dist_15',
    'Dist_Med',
    'Dist_85',
    'Dist_Avg'
])
accessModeOptions = ['drive', 'walk']

selectValues = widgets.Select(options=lstValues, value=('Dist_Med'), description = 'Select Variable')
selectAccessMode = widgets.Dropdown(options=accessModeOptions, value='drive', description='Access Mode')

# Set up a global variable to track whether the widgets have been changed
firstTime = False

# create output widget to display filtered DataFrame
output = widgets.Output()
hbox = widgets.HBox([selectValues, selectAccessMode])

# create interactive widget
interactive_output = widgets.interactive_output(plotit, {'variable':selectValues, 'access_mode': selectAccessMode})

display(hbox)
display(interactive_output)
display(output)
# Out:
# HBox(children=(Select(description='Select Variable', index=1, options=('Dist_15', 'Dist_Med', 'Dist_85', 'Dist…
# Output()
# Output()

# %%
sumStats.rename(columns={'Source': 'model_id'}).to_csv("crt-improvements-app/data/access-distance-stats.csv", index=False)
print("access-distance-stats.csv")
# Out:
# access-distance-stats.csv

# %%
import pandas as pd
import numpy as np

# Read stations data
df_stations1 = gs.df_stations[['station', 'N', 'County']]


# Output container
df_tdm_brd_county = pd.DataFrame()

for tdm_filename, tdm_sourcename in zip(tdm_filenames, tdm_sourcenames):
    print(tdm_sourcename)
    df_tdm_links = pd.read_csv(tdm_filename, low_memory=False)

    # Merge boarding and alighting station info (with County)
    df_tdm_1 = (
        df_tdm_links
        .merge(df_stations1[['N', 'station', 'County']], left_on="B", right_on="N", how="left")
        .rename(columns={"station": "brd_station", "County": "brd_county"})
        .merge(df_stations1[['N', 'station', 'County']], left_on="A", right_on="N", how="left")
        .rename(columns={"station": "alt_station", "County": "alt_county"})
        .drop(columns=['N_x', 'N_y'])
        .copy()
    )

    # Filter to relevant CRT access trips
    df_tdm_2 = df_tdm_1[
        ((df_tdm_1["brd_station"].notna()) & (df_tdm_1["A"] < 10000)) |
        ((df_tdm_1["alt_station"].notna()) & (df_tdm_1["B"] < 10000))
    ].copy()

    df_tdm_2 = df_tdm_2[df_tdm_2["Mode"].isin([80, 11])].copy()
    df_tdm_2["FromSkim_CRT"] = pd.to_numeric(df_tdm_2["FromSkim_CRT"], errors="coerce")

    # Prepare relevant columns
    df_tdm_3 = df_tdm_2[
        ['Mode', 'Period', 'AccessMode', 'brd_station', 'brd_county', 'alt_station', 'Riders', 'Distance']
    ].copy()

    # Group by County + Mode + AccessMode
    df_county_mode = (
        df_tdm_3
        .dropna(subset=["brd_station", "brd_county"])
        .groupby(['brd_county', 'Mode', 'AccessMode'], as_index=False)
        .apply(lambda x: pd.Series({
            'Brd_PA': x['Riders'].sum(),
            'Dist_15': weighted_quantile(x['Distance'].values, 0.15, x['Riders'].values, 10000),
            'Dist_Med': weighted_quantile(x['Distance'].values, 0.5, x['Riders'].values, 10000),
            'Dist_85': weighted_quantile(x['Distance'].values, 0.85, x['Riders'].values, 10000),
            'Dist_Avg': weighted_average(x['Distance'].values, x['Riders'].values)
        }))
        .reset_index()
    )

    # Group by County + Mode (All access modes combined)
    df_county_all = (
        df_tdm_3
        .dropna(subset=["brd_station", "brd_county"])
        .groupby(['brd_county', 'Mode'], as_index=False)
        .apply(lambda x: pd.Series({
            'Brd_PA': x['Riders'].sum(),
            'Dist_15': weighted_quantile(x['Distance'].values, 0.15, x['Riders'].values, 10000),
            'Dist_Med': weighted_quantile(x['Distance'].values, 0.5, x['Riders'].values, 10000),
            'Dist_85': weighted_quantile(x['Distance'].values, 0.85, x['Riders'].values, 10000),
            'Dist_Avg': weighted_average(x['Distance'].values, x['Riders'].values)
        }))
        .reset_index()
    )
    df_county_all["AccessMode"] = "All"

    # Combine both AccessMode-specific and "All"
    df_summary = pd.concat([df_county_mode, df_county_all], ignore_index=True)

    # Add source/notes metadata
    df_summary["Source"] = tdm_sourcename
    df_summary["Notes"] = "County-level summary of CRT boardings."

    # Reorder columns
    df_summary = df_summary[
        ["Source", "brd_county", "Mode", "AccessMode", "Brd_PA", "Dist_15", "Dist_Med", "Dist_85", "Dist_Avg", "Notes"]
    ].rename(columns={"brd_county": "County"})

    # Append to result container
    df_tdm_brd_county = pd.concat([df_tdm_brd_county, df_summary], ignore_index=True)

# Final output
display(df_tdm_brd_county)
# Out:
# v910-official__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# v910-official__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.14.4__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.14.4__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.16.2__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.16.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.17.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__RTP_MedDistAdj_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.4__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2138034675.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
#                      Source     County  Mode AccessMode   Brd_PA  Dist_15  \
# 0    v910-official__BY_2019      Davis  11.0       walk  1034.93     0.17
# 1    v910-official__BY_2019      Davis  80.0      drive  2959.38     1.44
# 2    v910-official__BY_2019  Salt Lake  11.0       walk  1669.52     0.19
# 3    v910-official__BY_2019  Salt Lake  80.0      drive  3478.83     2.42
# 4    v910-official__BY_2019       Utah  11.0       walk  1188.87     0.08
# ..                      ...        ...   ...        ...      ...      ...
# 187        E2.18.4__BY_2019  Salt Lake  80.0        All  3026.15     2.42
# 188        E2.18.4__BY_2019       Utah  11.0        All  1070.40     0.08
# 189        E2.18.4__BY_2019       Utah  80.0        All  5291.83     1.90
# 190        E2.18.4__BY_2019      Weber  11.0        All   414.59     0.37
# 191        E2.18.4__BY_2019      Weber  80.0        All  1952.34     1.89
#
#      Dist_Med  Dist_85  Dist_Avg                                   Notes
# 0        0.29     0.64  0.412758  County-level summary of CRT boardings.
# 1        2.70     4.34  2.929742  County-level summary of CRT boardings.
# 2        0.35     0.67  0.414255  County-level summary of CRT boardings.
# 3        4.34     7.52  4.856203  County-level summary of CRT boardings.
# 4        0.43     0.58  0.378081  County-level summary of CRT boardings.
# ..        ...      ...       ...                                     ...
# 187      4.02     5.97  4.152664  County-level summary of CRT boardings.
# 188      0.43     0.58  0.368766  County-level summary of CRT boardings.
# 189      3.47     6.29  3.919640  County-level summary of CRT boardings.
# 190      0.45     0.68  0.512463  County-level summary of CRT boardings.
# 191      3.62     5.82  3.922783  County-level summary of CRT boardings.
#
# [192 rows x 10 columns]

# %%
_df = df_tdm_brd_county

_df = _df[(_df['AccessMode'] == 'drive') & (_df['Mode'] == 80)]

_df[['Source','County','AccessMode','Dist_Med']].pivot_table(index='County', columns='Source', values='Dist_Med')
# Out:
# Source     E2.14.4__BY_2019  E2.14.4__RTP_2050  E2.16.2__BY_2019  \
# County
# Davis                  2.61               2.59              2.59
# Salt Lake              4.30               3.93              4.55
# Utah                   4.46               4.70              3.52
# Weber                  3.77               4.51              3.70
#
# Source     E2.16.3__BY_2019  E2.17.3__BY_2019  E2.18.2__BY_2019  \
# County
# Davis                  2.59              2.56              2.55
# Salt Lake              3.99              4.02              4.02
# Utah                   3.52              3.52              3.45
# Weber                  3.62              3.62              3.62
#
# Source     E2.18.2__RTP_2050  E2.18.2__RTP_MedDistAdj_2050  E2.18.3__BY_2019  \
# County
# Davis                   2.59                          2.59              2.55
# Salt Lake               4.10                          4.10              4.02
# Utah                    3.21                          3.97              3.46
# Weber                   4.66                          4.66              3.62
#
# Source     E2.18.4__BY_2019  v910-official__BY_2019  v910-official__RTP_2050
# County
# Davis                  2.56                    2.70                     2.59
# Salt Lake              4.02                    4.34                     3.85
# Utah                   3.47                    4.69                     4.74
# Weber                  3.62                    3.86                     4.51

# %%
# Add County first
boardings = boardings.merge(
    df_stations1[['station', 'County']],
    on='station',
    how='left'
)

# By County and access mode
boardings_total = (
    boardings.groupby(['County', 'AccessMode'])
    .apply(lambda x: pd.Series({
        'Brd_PA': sum(x['unlinked_weight_adj']),
        'Dist_15': weighted_quantile(x['AcDist'].values, 0.15, x['unlinked_weight_adj'].values, 10000),
        'Dist_Med': weighted_quantile(x['AcDist'].values, 0.5, x['unlinked_weight_adj'].values, 10000),
        'Dist_85': weighted_quantile(x['AcDist'].values, 0.85, x['unlinked_weight_adj'].values, 10000),
        'Dist_Avg': weighted_average(x['AcDist'].values, x['unlinked_weight_adj'].values)
    }))
    .reset_index()
)

# By County (all access modes)
boardings_all = (
    boardings.groupby('County')
    .apply(lambda x: pd.Series({
        'Brd_PA': sum(x['unlinked_weight_adj']),
        'Dist_15': weighted_quantile(x['AcDist'].values, 0.15, x['unlinked_weight_adj'].values, 10000),
        'Dist_Med': weighted_quantile(x['AcDist'].values, 0.5, x['unlinked_weight_adj'].values, 10000),
        'Dist_85': weighted_quantile(x['AcDist'].values, 0.85, x['unlinked_weight_adj'].values, 10000),
        'Dist_Avg': weighted_average(x['AcDist'].values, x['unlinked_weight_adj'].values)
    }))
    .reset_index()
)
boardings_all['AccessMode'] = 'All'

# Combine grouped + all
boardings_total = pd.concat([boardings_total, boardings_all], ignore_index=True)

# Add final metadata
boardings_total['Source'] = 'OBS'
boardings_total['Notes'] = 'Boardings represent all boardings, not just direct to CRT.'
boardings_total = boardings_total[
    ['Source', 'County', 'AccessMode', 'Brd_PA', 'Dist_15', 'Dist_Med', 'Dist_85', 'Dist_Avg', 'Notes']
]
# Out:
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2987133106.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boardings.groupby(['County', 'AccessMode'])
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\2987133106.py:23: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boardings.groupby('County')

# %%
_df = boardings_total

_df = _df[(_df['AccessMode'] == 'drive')]

_df[['Source','County','AccessMode','Dist_Med']]
# Out:
#   Source     County AccessMode  Dist_Med
# 0    OBS      Davis      drive      2.64
# 2    OBS  Salt Lake      drive      4.18
# 4    OBS       Utah      drive      3.25
# 6    OBS      Weber      drive      3.69

# %%
# Add County first
boardings = boardings.merge(
    df_stations1[['station', 'County']],
    on='station',
    how='left'
)

# By County and access mode
boardings_region_total = (
    boardings.groupby(['AccessMode'])
    .apply(lambda x: pd.Series({
        'Brd_PA': sum(x['unlinked_weight_adj']),
        'Dist_15': weighted_quantile(x['AcDist'].values, 0.15, x['unlinked_weight_adj'].values, 10000),
        'Dist_Med': weighted_quantile(x['AcDist'].values, 0.5, x['unlinked_weight_adj'].values, 10000),
        'Dist_85': weighted_quantile(x['AcDist'].values, 0.85, x['unlinked_weight_adj'].values, 10000),
        'Dist_Avg': weighted_average(x['AcDist'].values, x['unlinked_weight_adj'].values)
    }))
    .reset_index()
)


# Combine grouped + all
boardings_region_total = pd.concat([boardings_region_total], ignore_index=True)

# Add final metadata
boardings_region_total['Source'] = 'OBS'
boardings_region_total['Notes'] = 'Boardings represent all boardings, not just direct to CRT.'
boardings_region_total = boardings_region_total[
    ['Source', 'AccessMode', 'Brd_PA', 'Dist_15', 'Dist_Med', 'Dist_85', 'Dist_Avg', 'Notes']
]
# Out:
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\4012342960.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boardings.groupby(['AccessMode'])

# %%
_df = boardings_region_total

_df = _df[(_df['AccessMode'] == 'drive')]

_df[['Source','AccessMode','Dist_Med']]
# Out:
#   Source AccessMode  Dist_Med
# 0    OBS      drive  3.341861

# %%
import pandas as pd
import numpy as np

# Read stations data
df_stations1 = gs.df_stations[['station', 'N', 'County']]


# Output container
df_tdm_brd_region = pd.DataFrame()

for tdm_filename, tdm_sourcename in zip(tdm_filenames, tdm_sourcenames):
    print(tdm_sourcename)
    df_tdm_links = pd.read_csv(tdm_filename, low_memory=False)

    # Merge boarding and alighting station info (with County)
    df_tdm_1 = (
        df_tdm_links
        .merge(df_stations1[['N', 'station', 'County']], left_on="B", right_on="N", how="left")
        .rename(columns={"station": "brd_station", "County": "brd_county"})
        .merge(df_stations1[['N', 'station', 'County']], left_on="A", right_on="N", how="left")
        .rename(columns={"station": "alt_station", "County": "alt_county"})
        .drop(columns=['N_x', 'N_y'])
        .copy()
    )

    # Filter to relevant CRT access trips
    df_tdm_2 = df_tdm_1[
        ((df_tdm_1["brd_station"].notna()) & (df_tdm_1["A"] < 10000)) |
        ((df_tdm_1["alt_station"].notna()) & (df_tdm_1["B"] < 10000))
    ].copy()

    df_tdm_2 = df_tdm_2[df_tdm_2["Mode"].isin([80, 11])].copy()
    df_tdm_2["FromSkim_CRT"] = pd.to_numeric(df_tdm_2["FromSkim_CRT"], errors="coerce")

    # Prepare relevant columns
    df_tdm_3 = df_tdm_2[
        ['Mode', 'Period', 'AccessMode', 'brd_station', 'brd_county', 'alt_station', 'Riders', 'Distance']
    ].copy()

    # Group by County + Mode + AccessMode
    df_county_mode = (
        df_tdm_3
        .dropna(subset=["brd_station"])
        .groupby(['Mode', 'AccessMode'], as_index=False)
        .apply(lambda x: pd.Series({
            'Brd_PA': x['Riders'].sum(),
            'Dist_15': weighted_quantile(x['Distance'].values, 0.15, x['Riders'].values, 10000),
            'Dist_Med': weighted_quantile(x['Distance'].values, 0.5, x['Riders'].values, 10000),
            'Dist_85': weighted_quantile(x['Distance'].values, 0.85, x['Riders'].values, 10000),
            'Dist_Avg': weighted_average(x['Distance'].values, x['Riders'].values)
        }))
        .reset_index()
    )

    # Group by County + Mode (All access modes combined)
    df_county_all = (
        df_tdm_3
        .dropna(subset=["brd_station"])
        .groupby(['Mode'], as_index=False)
        .apply(lambda x: pd.Series({
            'Brd_PA': x['Riders'].sum(),
            'Dist_15': weighted_quantile(x['Distance'].values, 0.15, x['Riders'].values, 10000),
            'Dist_Med': weighted_quantile(x['Distance'].values, 0.5, x['Riders'].values, 10000),
            'Dist_85': weighted_quantile(x['Distance'].values, 0.85, x['Riders'].values, 10000),
            'Dist_Avg': weighted_average(x['Distance'].values, x['Riders'].values)
        }))
        .reset_index()
    )
    df_county_all["AccessMode"] = "All"

    # Combine both AccessMode-specific and "All"
    df_summary = pd.concat([df_county_mode, df_county_all], ignore_index=True)

    # Add source/notes metadata
    df_summary["Source"] = tdm_sourcename
    df_summary["Notes"] = "County-level summary of CRT boardings."

    # Reorder columns
    df_summary = df_summary[
        ["Source", "Mode", "AccessMode", "Brd_PA", "Dist_15", "Dist_Med", "Dist_85", "Dist_Avg", "Notes"]
    ]

    # Append to result container
    df_tdm_brd_region = pd.concat([df_tdm_brd_region, df_summary], ignore_index=True)

# Final output
display(df_tdm_brd_region)
# Out:
# v910-official__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# v910-official__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.14.4__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.14.4__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.16.2__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.16.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.17.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__RTP_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.2__RTP_MedDistAdj_2050
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.3__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# E2.18.4__BY_2019
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:42: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
# C:\Users\bhereth\AppData\Local\Temp\ipykernel_22976\1108571669.py:57: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_tdm_3
#                           Source  Mode AccessMode    Brd_PA  Dist_15  \
# 0         v910-official__BY_2019  11.0       walk   4334.59     0.17
# 1         v910-official__BY_2019  80.0      drive  12194.51     1.90
# 2         v910-official__BY_2019  11.0        All   4334.59     0.17
# 3         v910-official__BY_2019  80.0        All  12194.51     1.90
# 4        v910-official__RTP_2050  11.0       walk  18472.23     0.17
# 5        v910-official__RTP_2050  80.0      drive  43880.87     1.79
# 6        v910-official__RTP_2050  11.0        All  18472.23     0.17
# 7        v910-official__RTP_2050  80.0        All  43880.87     1.79
# 8               E2.14.4__BY_2019  11.0       walk   4359.05     0.17
# 9               E2.14.4__BY_2019  80.0      drive  13412.59     1.85
# 10              E2.14.4__BY_2019  11.0        All   4359.05     0.17
# 11              E2.14.4__BY_2019  80.0        All  13412.59     1.85
# 12             E2.14.4__RTP_2050  11.0       walk  18904.73     0.17
# 13             E2.14.4__RTP_2050  80.0      drive  41101.67     1.83
# 14             E2.14.4__RTP_2050  11.0        All  18904.73     0.17
# 15             E2.14.4__RTP_2050  80.0        All  41101.67     1.83
# 16              E2.16.2__BY_2019  11.0       walk   4279.33     0.17
# 17              E2.16.2__BY_2019  80.0      drive  13446.15     1.85
# 18              E2.16.2__BY_2019  11.0        All   4279.33     0.17
# 19              E2.16.2__BY_2019  80.0        All  13446.15     1.85
# 20              E2.16.3__BY_2019  11.0       walk   4286.26     0.17
# 21              E2.16.3__BY_2019  80.0      drive  13450.90     1.80
# 22              E2.16.3__BY_2019  11.0        All   4286.26     0.17
# 23              E2.16.3__BY_2019  80.0        All  13450.90     1.80
# 24              E2.17.3__BY_2019  11.0       walk   4269.81     0.17
# 25              E2.17.3__BY_2019  80.0      drive  13460.72     1.83
# 26              E2.17.3__BY_2019  11.0        All   4269.81     0.17
# 27              E2.17.3__BY_2019  80.0        All  13460.72     1.83
# 28              E2.18.2__BY_2019  11.0       walk   4233.67     0.17
# 29              E2.18.2__BY_2019  80.0      drive  13490.86     1.76
# 30              E2.18.2__BY_2019  11.0        All   4233.67     0.17
# 31              E2.18.2__BY_2019  80.0        All  13490.86     1.76
# 32             E2.18.2__RTP_2050  11.0       walk  18026.08     0.17
# 33             E2.18.2__RTP_2050  80.0      drive  48208.32     1.59
# 34             E2.18.2__RTP_2050  11.0        All  18026.08     0.17
# 35             E2.18.2__RTP_2050  80.0        All  48208.32     1.59
# 36  E2.18.2__RTP_MedDistAdj_2050  11.0       walk  18451.65     0.17
# 37  E2.18.2__RTP_MedDistAdj_2050  80.0      drive  45011.40     1.78
# 38  E2.18.2__RTP_MedDistAdj_2050  11.0        All  18451.65     0.17
# 39  E2.18.2__RTP_MedDistAdj_2050  80.0        All  45011.40     1.78
# 40              E2.18.3__BY_2019  11.0       walk   4250.88     0.17
# 41              E2.18.3__BY_2019  80.0      drive  13467.61     1.79
# 42              E2.18.3__BY_2019  11.0        All   4250.88     0.17
# 43              E2.18.3__BY_2019  80.0        All  13467.61     1.79
# 44              E2.18.4__BY_2019  11.0       walk   4260.82     0.17
# 45              E2.18.4__BY_2019  80.0      drive  13459.75     1.80
# 46              E2.18.4__BY_2019  11.0        All   4260.82     0.17
# 47              E2.18.4__BY_2019  80.0        All  13459.75     1.80
#
#     Dist_Med  Dist_85  Dist_Avg                                   Notes
# 0       0.40     0.66  0.414053  County-level summary of CRT boardings.
# 1       3.77     8.14  5.057928  County-level summary of CRT boardings.
# 2       0.40     0.66  0.414053  County-level summary of CRT boardings.
# 3       3.77     8.14  5.057928  County-level summary of CRT boardings.
# 4       0.29     0.64  0.364819  County-level summary of CRT boardings.
# 5       3.69     8.01  4.823302  County-level summary of CRT boardings.
# 6       0.29     0.64  0.364819  County-level summary of CRT boardings.
# 7       3.69     8.01  4.823302  County-level summary of CRT boardings.
# 8       0.40     0.66  0.414664  County-level summary of CRT boardings.
# 9       3.53     7.35  4.554548  County-level summary of CRT boardings.
# 10      0.40     0.66  0.414664  County-level summary of CRT boardings.
# 11      3.53     7.35  4.554548  County-level summary of CRT boardings.
# 12      0.29     0.64  0.365671  County-level summary of CRT boardings.
# 13      3.80     8.30  4.983347  County-level summary of CRT boardings.
# 14      0.29     0.64  0.365671  County-level summary of CRT boardings.
# 15      3.80     8.30  4.983347  County-level summary of CRT boardings.
# 16      0.40     0.65  0.413777  County-level summary of CRT boardings.
# 17      3.48     6.25  4.123371  County-level summary of CRT boardings.
# 18      0.40     0.65  0.413777  County-level summary of CRT boardings.
# 19      3.48     6.25  4.123371  County-level summary of CRT boardings.
# 20      0.40     0.65  0.413745  County-level summary of CRT boardings.
# 21      3.32     5.68  3.658893  County-level summary of CRT boardings.
# 22      0.40     0.65  0.413745  County-level summary of CRT boardings.
# 23      3.32     5.68  3.658893  County-level summary of CRT boardings.
# 24      0.40     0.65  0.413812  County-level summary of CRT boardings.
# 25      3.33     5.72  3.689134  County-level summary of CRT boardings.
# 26      0.40     0.65  0.413812  County-level summary of CRT boardings.
# 27      3.33     5.72  3.689134  County-level summary of CRT boardings.
# 28      0.40     0.65  0.413786  County-level summary of CRT boardings.
# 29      3.32     5.97  3.751480  County-level summary of CRT boardings.
# 30      0.40     0.65  0.413786  County-level summary of CRT boardings.
# 31      3.32     5.97  3.751480  County-level summary of CRT boardings.
# 32      0.29     0.66  0.370952  County-level summary of CRT boardings.
# 33      3.44     7.02  4.280292  County-level summary of CRT boardings.
# 34      0.29     0.66  0.370952  County-level summary of CRT boardings.
# 35      3.44     7.02  4.280292  County-level summary of CRT boardings.
# 36      0.29     0.65  0.370041  County-level summary of CRT boardings.
# 37      3.63     7.34  4.482924  County-level summary of CRT boardings.
# 38      0.29     0.65  0.370041  County-level summary of CRT boardings.
# 39      3.63     7.34  4.482924  County-level summary of CRT boardings.
# 40      0.40     0.65  0.413865  County-level summary of CRT boardings.
# 41      3.32     5.83  3.724408  County-level summary of CRT boardings.
# 42      0.40     0.65  0.413865  County-level summary of CRT boardings.
# 43      3.32     5.83  3.724408  County-level summary of CRT boardings.
# 44      0.40     0.65  0.413876  County-level summary of CRT boardings.
# 45      3.33     5.76  3.707233  County-level summary of CRT boardings.
# 46      0.40     0.65  0.413876  County-level summary of CRT boardings.
# 47      3.33     5.76  3.707233  County-level summary of CRT boardings.

# %%
_df = df_tdm_brd_region

_df = _df[(_df['AccessMode'] == 'drive') & (_df['Mode'] == 80)]

_df[['Source','AccessMode','Dist_Med']]
# Out:
#                           Source AccessMode  Dist_Med
# 1         v910-official__BY_2019      drive      3.77
# 5        v910-official__RTP_2050      drive      3.69
# 9               E2.14.4__BY_2019      drive      3.53
# 13             E2.14.4__RTP_2050      drive      3.80
# 17              E2.16.2__BY_2019      drive      3.48
# 21              E2.16.3__BY_2019      drive      3.32
# 25              E2.17.3__BY_2019      drive      3.33
# 29              E2.18.2__BY_2019      drive      3.32
# 33             E2.18.2__RTP_2050      drive      3.44
# 37  E2.18.2__RTP_MedDistAdj_2050      drive      3.63
# 41              E2.18.3__BY_2019      drive      3.32
# 45              E2.18.4__BY_2019      drive      3.33
